# %% [markdown]
# # Classification

# %%
import io
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
import operator
import math

# %%
data=pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Removing the unnecessary column

# %%
data.drop('Id',axis=1,inplace=True)
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
train, test = train_test_split(data, test_size=0.33, random_state=42) 
test.index = np.arange(0, len(test))
print(test)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0             6.1           2.8            4.7           1.2  Iris-versicolor
# 1             5.7           3.8            1.7           0.3      Iris-setosa
# 2             7.7           2.6            6.9           2.3   Iris-virginica
# 3             6.0           2.9            4.5           1.5  Iris-versicolor
# 4             6.8           2.8            4.8           1.4  Iris-versicolor
# 5             5.4           3.4            1.5           0.4      Iris-setosa
# 6             5.6           2.9            3.6           1.3  Iris-versicolor
# 7             6.9           3.1            5.1           2.3   Iris-virginica
# 8             6.2           2.2            4.5           1.5  Iris-versicolor
# 9             5.8           2.7            3.9           1.2  Iris-versicolor
# 10            6.5           3.2            5.1           2.0   Iris-virginica
# 11            4.8           3.0            1.4           0.1      Iris-setosa
# 12            5.5           3.5            1.3           0.2      Iris-setosa
# 13            4.9           3.1            1.5           0.1      Iris-setosa
# 14            5.1           3.8            1.5           0.3      Iris-setosa
# 15            6.3           3.3            4.7           1.6  Iris-versicolor
# 16            6.5           3.0            5.8           2.2   Iris-virginica
# 17            5.6           2.5            3.9           1.1  Iris-versicolor
# 18            5.7           2.8            4.5           1.3  Iris-versicolor
# 19            6.4           2.8            5.6           2.2   Iris-virginica
# 20            4.7           3.2            1.6           0.2      Iris-setosa
# 21            6.1           3.0            4.9           1.8   Iris-virginica
# 22            5.0           3.4            1.6           0.4      Iris-setosa
# 23            6.4           2.8            5.6           2.1   Iris-virginica
# 24            7.9           3.8            6.4           2.0   Iris-virginica
# 25            6.7           3.0            5.2           2.3   Iris-virginica
# 26            6.7           2.5            5.8           1.8   Iris-virginica
# 27            6.8           3.2            5.9           2.3   Iris-virginica
# 28            4.8           3.0            1.4           0.3      Iris-setosa
# 29            4.8           3.1            1.6           0.2      Iris-setosa
# 30            4.6           3.6            1.0           0.2      Iris-setosa
# 31            5.7           4.4            1.5           0.4      Iris-setosa
# 32            6.7           3.1            4.4           1.4  Iris-versicolor
# 33            4.8           3.4            1.6           0.2      Iris-setosa
# 34            4.4           3.2            1.3           0.2      Iris-setosa
# 35            6.3           2.5            5.0           1.9   Iris-virginica
# 36            6.4           3.2            4.5           1.5  Iris-versicolor
# 37            5.2           3.5            1.5           0.2      Iris-setosa
# 38            5.0           3.6            1.4           0.2      Iris-setosa
# 39            5.2           4.1            1.5           0.1      Iris-setosa
# 40            5.8           2.7            5.1           1.9   Iris-virginica
# 41            6.0           3.4            4.5           1.6  Iris-versicolor
# 42            6.7           3.1            4.7           1.5  Iris-versicolor
# 43            5.4           3.9            1.3           0.4      Iris-setosa
# 44            5.4           3.7            1.5           0.2      Iris-setosa
# 45            5.5           2.4            3.7           1.0  Iris-versicolor
# 46            6.3           2.8            5.1           1.5   Iris-virginica
# 47            6.4           3.1            5.5           1.8   Iris-virginica
# 48            6.6           3.0            4.4           1.4  Iris-versicolor
# 49            7.2           3.6            6.1           2.5   Iris-virginica

# %%
def euclideanDistance(data1, data2, length):
    distance = 0
    for x in range(length):
        #print("Operand:",data1[x],", ",data2[x])
        distance += pow((data1[x] - data2[x]), 2)
    return math.sqrt(distance)

# %%
def ManhattanDistance(data1, data2, length):
    data1 = np.asarray(data1[:4])
    data2 = np.asarray(data2[:4])
    return sum(abs(data1 - data2))

# %%
def CosineDistance(data1, data2, length):
    data1 = np.asarray(data1[:4])
    data2 = np.asarray(data2[:4])
    dot = np.dot(data1, data2)
    norma = np.linalg.norm(data1)
    normb = np.linalg.norm(data2)
    cos = dot / (norma * normb)
    return cos#CD = np.vectorize(cosineDistance)

# %%
def getNeighbors(trainingSet, testInstance, k, distance_metric):
    distances = []
    #Make this length a list of the feature indexes which we want to use
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        if(distance_metric=='Euclidean'):
            train=(trainingSet.iloc[x].tolist())
            dist = euclideanDistance(testInstance, train, length)
            #print(dist)
        elif(distance_metric=='Manhattan'):
            train=(trainingSet.iloc[x].tolist())
            dist = ManhattanDistance(testInstance, train, length)
            #print(dist)
        elif(distance_metric=='Cosine'):
            train=(trainingSet.iloc[x].tolist())
            dist = CosineDistance(testInstance, train, length)
            #print(dist)
        distances.append((train, dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

# %%
def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

# %%
#Calculate accuracy of predictions
def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        test=(testSet.iloc[x].tolist())
        if test[-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0

# %%
def KNN_predict(trainingSet, testSet, k, distance_metric):
    predictions=[]
    #print(len(testSet))
    for x in range(len(testSet)):
        test=(testSet.iloc[x].tolist())
        neighbors = getNeighbors(trainingSet, test, k, distance_metric)
        result = getResponse(neighbors)
        predictions.append(result)
        if(distance_metric=='Euclidean'):
            print('> predicted=' + repr(result) + ', actual=' + repr(test[-1]))
        elif(distance_metric=='Manhattan'):
            print('> predicted=' + repr(result) + ', actual=' + repr(test[-1]))
        elif(distance_metric=='Cosine'):
            print('> predicted=' + repr(result) + ', actual=' + repr(test[-1]))

    accuracy = getAccuracy(testSet, predictions)
    if(distance_metric=='Euclidean'):
        print('Accuracy: ' + repr(accuracy) + '%')
    elif(distance_metric=='Manhattan'):
        print('Accuracy: ' + repr(accuracy) + '%')
    elif(distance_metric=='Cosine'):
        print('Accuracy: ' + repr(accuracy) + '%')

# %%
K=3
print('****************************Euclidean***************************************')
KNN_predict(train, test, K, distance_metric='Euclidean')
print('****************************Manhattan***************************************')
KNN_predict(train, test, K, distance_metric='Manhattan')
print('****************************Cosine***************************************')
KNN_predict(train, test, K, distance_metric='Cosine')
# Out:
# ****************************Euclidean***************************************
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# Accuracy: 98.0%
# ****************************Manhattan***************************************
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# Accuracy: 98.0%
# ****************************Cosine***************************************
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-virginica', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-virginica'
# > predicted='Iris-setosa', actual='Iris-versicolor'
# > predicted='Iris-setosa', actual='Iris-virginica'
# Accuracy: 0.0%

# %% [markdown]
# # Regression

# %%
data=pd.read_csv('Real_estate_valuation.csv')
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %% [markdown]
# # Removing the unnecessary column

# %%
data.drop('No',axis=1,inplace=True)
data.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
train, test = train_test_split(data, test_size=0.33, random_state=42) 
test.index = np.arange(0, len(test))
print(test)
# Out:
#      X1 transaction date  X2 house age  \
# 0               2013.167           1.1
# 1               2013.000          13.2
# 2               2013.083           0.0
# 3               2012.917          12.7
# 4               2012.667          20.2
# 5               2013.583          32.5
# 6               2012.917          15.9
# 7               2013.250          16.2
# 8               2012.917          31.9
# 9               2013.583           6.6
# 10              2013.500          25.3
# 11              2013.500           4.0
# 12              2012.833           5.1
# 13              2012.833          31.7
# 14              2013.083          38.6
# 15              2013.417          14.7
# 16              2013.417          33.6
# 17              2012.833           3.4
# 18              2012.917          17.3
# 19              2013.083          15.1
# 20              2013.000          30.9
# 21              2013.417          17.9
# 22              2013.250           5.4
# 23              2013.500          13.6
# 24              2012.750          13.5
# 25              2012.833          12.7
# 26              2012.833          16.2
# 27              2012.833           0.0
# 28              2012.917          40.9
# 29              2013.083          41.3
# ..                   ...           ...
# 107             2012.833          18.4
# 108             2013.167          26.6
# 109             2013.167          13.0
# 110             2013.417          31.4
# 111             2012.833          12.7
# 112             2013.417           9.7
# 113             2013.083           7.1
# 114             2012.833          10.3
# 115             2012.833           0.0
# 116             2013.083          16.2
# 117             2012.667          30.6
# 118             2013.333          21.7
# 119             2013.500          12.3
# 120             2013.417          17.2
# 121             2013.500          16.4
# 122             2013.250           0.0
# 123             2013.000           1.0
# 124             2013.000          13.0
# 125             2013.417          20.3
# 126             2013.500          15.2
# 127             2012.667           1.5
# 128             2012.833          13.9
# 129             2012.833          15.0
# 130             2013.417          20.0
# 131             2013.083          34.0
# 132             2012.917           2.1
# 133             2012.833          15.7
# 134             2013.583           4.0
# 135             2012.917          38.3
# 136             2013.000          22.8
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                 193.58450                                6
# 1                                 492.23130                                5
# 2                                 274.01440                                1
# 3                                 170.12890                                1
# 4                                2185.12800                                3
# 5                                 424.54420                                8
# 6                                 289.32480                                5
# 7                                 289.32480                                5
# 8                                1146.32900                                0
# 9                                  90.45606                                9
# 10                               1583.72200                                3
# 11                               2147.37600                                3
# 12                               1867.23300                                2
# 13                               1160.63200                                0
# 14                                804.68970                                4
# 15                               1717.19300                                2
# 16                                371.24950                                8
# 17                                 56.47425                                7
# 18                               2261.43200                                4
# 19                                383.28050                                7
# 20                               6396.28300                                1
# 21                               1783.18000                                3
# 22                                390.56840                                5
# 23                                319.07080                                6
# 24                               4197.34900                                0
# 25                                187.48230                                1
# 26                               4074.73600                                0
# 27                                274.01440                                1
# 28                                167.59890                                5
# 29                                401.88070                                4
# ..                                      ...                              ...
# 107                              2674.96100                                3
# 108                               482.75810                                5
# 109                               732.85280                                0
# 110                               592.50060                                2
# 111                               170.12890                                1
# 112                               421.47900                                5
# 113                               451.24380                                5
# 114                              3079.89000                                0
# 115                               185.42960                                0
# 116                               289.32480                                5
# 117                               143.83830                                8
# 118                              1055.06700                                0
# 119                              1360.13900                                1
# 120                               390.56840                                5
# 121                              3780.59000                                0
# 122                               292.99780                                6
# 123                               193.58450                                6
# 124                               750.07040                                2
# 125                               287.60250                                6
# 126                              3771.89500                                0
# 127                                23.38284                                7
# 128                              4573.77900                                0
# 129                              1828.31900                                2
# 130                              1626.08300                                3
# 131                               157.60520                                7
# 132                               451.24380                                5
# 133                               815.93140                                4
# 134                              2147.37600                                3
# 135                               642.69850                                3
# 136                               707.90670                                2
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.96571     121.54089                        45.1
# 1       24.96515     121.53737                        42.3
# 2       24.97480     121.53059                        52.2
# 3       24.97371     121.52984                        37.3
# 4       24.96322     121.51237                        22.8
# 5       24.97587     121.53913                        36.3
# 6       24.98203     121.54348                        53.0
# 7       24.98203     121.54348                        51.4
# 8       24.94920     121.53076                        16.1
# 9       24.97433     121.54310                        59.0
# 10      24.96622     121.51709                        30.6
# 11      24.96299     121.51284                        30.7
# 12      24.98407     121.51748                        35.6
# 13      24.94968     121.53009                        13.7
# 14      24.97838     121.53477                        62.9
# 15      24.96447     121.51649                        30.5
# 16      24.97254     121.54059                        41.9
# 17      24.95744     121.53711                        54.4
# 18      24.96182     121.51222                        29.5
# 19      24.96735     121.54464                        43.7
# 20      24.94375     121.47883                        12.2
# 21      24.96731     121.51486                        22.1
# 22      24.97937     121.54245                        49.5
# 23      24.96495     121.54277                        47.4
# 24      24.93885     121.50383                        18.6
# 25      24.97388     121.52981                        28.5
# 26      24.94235     121.50357                        14.7
# 27      24.97480     121.53059                        45.4
# 28      24.96630     121.54026                        41.0
# 29      24.98326     121.54460                        35.1
# ..           ...           ...                         ...
# 107     24.96143     121.50827                        25.7
# 108     24.97433     121.53863                        37.5
# 109     24.97668     121.52518                        39.0
# 110     24.97260     121.53561                        34.1
# 111     24.97371     121.52984                        32.9
# 112     24.98246     121.54477                        49.3
# 113     24.97563     121.54694                        57.1
# 114     24.95460     121.56627                        24.7
# 115     24.97110     121.53170                        55.3
# 116     24.98203     121.54348                        55.0
# 117     24.98155     121.54142                        53.3
# 118     24.96211     121.54928                        23.1
# 119     24.95204     121.54842                        29.5
# 120     24.97937     121.54245                        40.1
# 121     24.93293     121.51203                        45.1
# 122     24.97744     121.54458                        70.1
# 123     24.96571     121.54089                        50.7
# 124     24.97371     121.54951                        37.0
# 125     24.98042     121.54228                        46.7
# 126     24.93363     121.51158                        29.3
# 127     24.96772     121.54102                        47.7
# 128     24.94867     121.49507                        19.2
# 129     24.96464     121.51531                        20.9
# 130     24.96622     121.51668                        29.4
# 131     24.96628     121.54196                        39.1
# 132     24.97563     121.54694                        45.5
# 133     24.97886     121.53464                        38.1
# 134     24.96299     121.51284                        28.4
# 135     24.97559     121.53713                        31.5
# 136     24.98100     121.54713                        36.6
#
# [137 rows x 7 columns]

# %%
def euclideanDistance(data1, data2, length):
    distance = 0
    for x in range(length):
        #print("Operand:",data1[x],", ",data2[x])
        distance += pow((data1[x] - data2[x]), 2)
    return math.sqrt(distance)

# %%
def ManhattanDistanceReg(data1, data2, length):
    data1 = np.asarray(data1[:6])
    data2 = np.asarray(data2[:6])
    return sum(abs(data1 - data2))

# %%
def CosineDistanceReg(data1, data2, length):
    data1 = np.asarray(data1[:6])
    data2 = np.asarray(data2[:6])
    dot = np.dot(data1, data2)
    norma = np.linalg.norm(data1)
    normb = np.linalg.norm(data2)
    cos = dot / (norma * normb)
    return cos#CD = np.vectorize(cosineDistance)

# %%
def getNeighbors(trainingSet, testInstance, k, distance_metric):
    distances = []
    #Make this length a list of the feature indexes which we want to use
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        if(distance_metric=='Euclidean'):
            train=(trainingSet.iloc[x].tolist())
            dist = euclideanDistance(testInstance, train, length)
            #print(dist)
        elif(distance_metric=='Manhattan'):
            train=(trainingSet.iloc[x].tolist())
            dist = ManhattanDistanceReg(testInstance, train, length)
            #print(dist)
        elif(distance_metric=='Cosine'):
            train=(trainingSet.iloc[x].tolist())
            dist = CosineDistanceReg(testInstance, train, length)
            #print(dist)
        distances.append((train, dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

# %%
def getResponse_Reg(neighbors, k):
    sum1=0
    for x in range(len(neighbors)):
        sum1 += neighbors[x][-1]
    result=sum1/k
    return result

# %%
def RMSE_Reg(testSet, predictions):
    sqerr=0
    for x in range(len(testSet)):
        test=(testSet.iloc[x].tolist())
        err=test[-1]-predictions[x]
        sqerr+=pow(err, 2)
    mse=sqerr/len(testSet)
    rmse=pow(mse, 0.5)
        
    return rmse

# %%
def KNN_predict_Reg(trainingSet, testSet, k, distance_metric):
    predictions=[]
    #print(len(testSet))
    for x in range(len(testSet)):
        test=(testSet.iloc[x].tolist())
        neighbors = getNeighbors(trainingSet, test, k, distance_metric)
        result = getResponse_Reg(neighbors, k)
        predictions.append(result)
        if(distance_metric=='Euclidean'):
            print('> predicted=' + repr(result) + ', actual=' + repr(test[-1]))
        elif(distance_metric=='Manhattan'):
            print('> predicted=' + repr(result) + ', actual=' + repr(test[-1]))
        elif(distance_metric=='Cosine'):
            print('> predicted=' + repr(result) + ', actual=' + repr(test[-1]))

    rmse = RMSE_Reg(testSet, predictions)
    if(distance_metric=='Euclidean'):
        print('Root Mean Square Error: ' + repr(rmse) + '%')
    elif(distance_metric=='Manhattan'):
        print('Root Mean Square Error: ' + repr(rmse) + '%')
    elif(distance_metric=='Cosine'):
        print('Root Mean Square Error: ' + repr(rmse) + '%')

# %%
K=3
print('****************************Euclidean***************************************')
KNN_predict_Reg(train, test, K, distance_metric='Euclidean')
print('****************************Manhattan***************************************')
KNN_predict_Reg(train, test, K, distance_metric='Manhattan')
print('****************************Cosine***************************************')
KNN_predict_Reg(train, test, K, distance_metric='Cosine')
# Out:
# ****************************Euclidean***************************************
# > predicted=49.46666666666667, actual=45.1
# > predicted=36.5, actual=42.3
# > predicted=41.666666666666664, actual=52.2
# > predicted=37.53333333333333, actual=37.3
# > predicted=25.066666666666666, actual=22.8
# > predicted=37.43333333333334, actual=36.3
# > predicted=45.0, actual=53.0
# > predicted=47.96666666666667, actual=51.4
# > predicted=15.200000000000001, actual=16.1
# > predicted=60.5, actual=59.0
# > predicted=25.833333333333332, actual=30.6
# > predicted=32.13333333333333, actual=30.7
# > predicted=26.26666666666667, actual=35.6
# > predicted=15.200000000000001, actual=13.7
# > predicted=31.966666666666665, actual=62.9
# > predicted=27.7, actual=30.5
# > predicted=40.53333333333333, actual=41.9
# > predicted=53.73333333333333, actual=54.4
# > predicted=26.599999999999998, actual=29.5
# > predicted=41.666666666666664, actual=43.7
# > predicted=17.066666666666666, actual=12.2
# > predicted=25.600000000000005, actual=22.1
# > predicted=46.666666666666664, actual=49.5
# > predicted=48.300000000000004, actual=47.4
# > predicted=18.96666666666667, actual=18.6
# > predicted=41.86666666666667, actual=28.5
# > predicted=18.933333333333334, actual=14.7
# > predicted=41.666666666666664, actual=45.4
# > predicted=43.03333333333334, actual=41.0
# > predicted=32.800000000000004, actual=35.1
# > predicted=14.4, actual=22.1
# > predicted=25.46666666666667, actual=28.9
# > predicted=39.6, actual=30.5
# > predicted=38.96666666666666, actual=26.5
# > predicted=45.6, actual=49.3
# > predicted=37.63333333333333, actual=37.0
# > predicted=54.73333333333333, actual=56.3
# > predicted=18.666666666666668, actual=15.4
# > predicted=35.4, actual=48.5
# > predicted=36.666666666666664, actual=63.3
# > predicted=41.23333333333333, actual=50.5
# > predicted=39.333333333333336, actual=42.2
# > predicted=50.9, actual=37.9
# > predicted=40.300000000000004, actual=37.5
# > predicted=40.23333333333333, actual=40.5
# > predicted=44.36666666666667, actual=57.4
# > predicted=32.833333333333336, actual=26.5
# > predicted=21.099999999999998, actual=21.8
# > predicted=53.73333333333333, actual=49.7
# > predicted=50.9, actual=47.1
# > predicted=49.46666666666667, actual=49.0
# > predicted=56.666666666666664, actual=60.7
# > predicted=38.833333333333336, actual=33.1
# > predicted=35.23333333333333, actual=41.0
# > predicted=37.66666666666667, actual=36.5
# > predicted=18.666666666666668, actual=20.0
# > predicted=37.233333333333334, actual=34.7
# > predicted=23.900000000000002, actual=30.6
# > predicted=25.066666666666666, actual=25.6
# > predicted=47.96666666666667, actual=46.2
# > predicted=26.03333333333333, actual=27.7
# > predicted=25.266666666666666, actual=27.0
# > predicted=18.666666666666668, actual=15.6
# > predicted=17.733333333333334, actual=15.5
# > predicted=17.066666666666666, actual=11.2
# > predicted=25.600000000000005, actual=23.7
# > predicted=27.333333333333332, actual=24.6
# > predicted=34.36666666666667, actual=42.0
# > predicted=43.699999999999996, actual=29.8
# > predicted=27.333333333333332, actual=28.9
# > predicted=44.79999999999999, actual=48.1
# > predicted=38.833333333333336, actual=36.8
# > predicted=53.73333333333333, actual=53.5
# > predicted=49.03333333333333, actual=51.6
# > predicted=37.800000000000004, actual=38.8
# > predicted=37.333333333333336, actual=37.4
# > predicted=46.5, actual=40.6
# > predicted=47.20000000000001, actual=37.2
# > predicted=40.300000000000004, actual=25.0
# > predicted=26.599999999999998, actual=23.5
# > predicted=29.733333333333334, actual=35.6
# > predicted=45.0, actual=46.1
# > predicted=26.76666666666667, actual=26.2
# > predicted=53.73333333333333, actual=42.7
# > predicted=26.900000000000002, actual=23.9
# > predicted=26.03333333333333, actual=32.1
# > predicted=39.93333333333334, actual=38.3
# > predicted=39.3, actual=40.8
# > predicted=27.7, actual=30.8
# > predicted=32.833333333333336, actual=34.6
# > predicted=37.7, actual=29.3
# > predicted=39.93333333333334, actual=35.5
# > predicted=30.900000000000002, actual=34.1
# > predicted=45.06666666666666, actual=54.8
# > predicted=41.43333333333333, actual=42.3
# > predicted=35.4, actual=30.0
# > predicted=25.833333333333332, actual=21.3
# > predicted=40.53333333333333, actual=38.6
# > predicted=25.066666666666666, actual=28.1
# > predicted=44.79999999999999, actual=55.0
# > predicted=26.599999999999998, actual=24.4
# > predicted=43.666666666666664, actual=28.5
# > predicted=34.833333333333336, actual=7.6
# > predicted=22.96666666666667, actual=22.3
# > predicted=53.73333333333333, actual=62.1
# > predicted=54.73333333333333, actual=50.0
# > predicted=25.833333333333332, actual=31.3
# > predicted=21.099999999999998, actual=25.7
# > predicted=39.93333333333334, actual=37.5
# > predicted=46.5, actual=39.0
# > predicted=36.0, actual=34.1
# > predicted=37.53333333333333, actual=32.9
# > predicted=40.1, actual=49.3
# > predicted=39.36666666666667, actual=57.1
# > predicted=36.6, actual=24.7
# > predicted=48.43333333333334, actual=55.3
# > predicted=47.96666666666667, actual=55.0
# > predicted=43.13333333333333, actual=53.3
# > predicted=22.96666666666667, actual=23.1
# > predicted=27.333333333333332, actual=29.5
# > predicted=35.233333333333334, actual=40.1
# > predicted=21.400000000000002, actual=45.1
# > predicted=68.86666666666666, actual=70.1
# > predicted=49.46666666666667, actual=50.7
# > predicted=40.300000000000004, actual=37.0
# > predicted=54.53333333333333, actual=46.7
# > predicted=16.599999999999998, actual=29.3
# > predicted=53.73333333333333, actual=47.7
# > predicted=14.466666666666667, actual=19.2
# > predicted=25.600000000000005, actual=20.9
# > predicted=25.833333333333332, actual=29.4
# > predicted=43.23333333333333, actual=39.1
# > predicted=39.36666666666667, actual=45.5
# > predicted=29.733333333333334, actual=38.1
# > predicted=32.13333333333333, actual=28.4
# > predicted=46.6, actual=31.5
# > predicted=46.5, actual=36.6
# Root Mean Square Error: 7.696583436413456%
# ****************************Manhattan***************************************
# > predicted=49.46666666666667, actual=45.1
# > predicted=36.5, actual=42.3
# > predicted=41.666666666666664, actual=52.2
# > predicted=37.53333333333333, actual=37.3
# > predicted=25.066666666666666, actual=22.8
# > predicted=37.43333333333334, actual=36.3
# > predicted=45.0, actual=53.0
# > predicted=47.96666666666667, actual=51.4
# > predicted=15.200000000000001, actual=16.1
# > predicted=60.5, actual=59.0
# > predicted=25.833333333333332, actual=30.6
# > predicted=32.13333333333333, actual=30.7
# > predicted=26.26666666666667, actual=35.6
# > predicted=15.200000000000001, actual=13.7
# > predicted=31.96666666666667, actual=62.9
# > predicted=27.7, actual=30.5
# > predicted=39.03333333333333, actual=41.9
# > predicted=56.03333333333333, actual=54.4
# > predicted=26.599999999999998, actual=29.5
# > predicted=41.666666666666664, actual=43.7
# > predicted=17.066666666666666, actual=12.2
# > predicted=25.599999999999998, actual=22.1
# > predicted=44.900000000000006, actual=49.5
# > predicted=48.36666666666667, actual=47.4
# > predicted=18.96666666666667, actual=18.6
# > predicted=45.13333333333333, actual=28.5
# > predicted=18.933333333333334, actual=14.7
# > predicted=41.666666666666664, actual=45.4
# > predicted=43.63333333333333, actual=41.0
# > predicted=32.800000000000004, actual=35.1
# > predicted=14.4, actual=22.1
# > predicted=25.46666666666667, actual=28.9
# > predicted=39.333333333333336, actual=30.5
# > predicted=38.96666666666666, actual=26.5
# > predicted=46.46666666666667, actual=49.3
# > predicted=37.63333333333333, actual=37.0
# > predicted=54.73333333333333, actual=56.3
# > predicted=15.133333333333335, actual=15.4
# > predicted=35.4, actual=48.5
# > predicted=36.666666666666664, actual=63.3
# > predicted=41.23333333333333, actual=50.5
# > predicted=39.333333333333336, actual=42.2
# > predicted=50.86666666666667, actual=37.9
# > predicted=40.300000000000004, actual=37.5
# > predicted=40.23333333333333, actual=40.5
# > predicted=44.36666666666667, actual=57.4
# > predicted=32.833333333333336, actual=26.5
# > predicted=21.099999999999998, actual=21.8
# > predicted=56.03333333333333, actual=49.7
# > predicted=50.86666666666667, actual=47.1
# > predicted=49.46666666666667, actual=49.0
# > predicted=56.666666666666664, actual=60.7
# > predicted=40.73333333333333, actual=33.1
# > predicted=35.23333333333333, actual=41.0
# > predicted=37.66666666666667, actual=36.5
# > predicted=15.133333333333335, actual=20.0
# > predicted=37.233333333333334, actual=34.7
# > predicted=23.900000000000002, actual=30.6
# > predicted=25.066666666666666, actual=25.6
# > predicted=47.96666666666667, actual=46.2
# > predicted=26.03333333333333, actual=27.7
# > predicted=25.266666666666666, actual=27.0
# > predicted=15.133333333333335, actual=15.6
# > predicted=17.733333333333334, actual=15.5
# > predicted=17.066666666666666, actual=11.2
# > predicted=25.599999999999998, actual=23.7
# > predicted=26.76666666666667, actual=24.6
# > predicted=34.36666666666667, actual=42.0
# > predicted=43.699999999999996, actual=29.8
# > predicted=27.333333333333332, actual=28.9
# > predicted=37.833333333333336, actual=48.1
# > predicted=38.833333333333336, actual=36.8
# > predicted=56.03333333333333, actual=53.5
# > predicted=49.03333333333333, actual=51.6
# > predicted=37.800000000000004, actual=38.8
# > predicted=37.333333333333336, actual=37.4
# > predicted=46.5, actual=40.6
# > predicted=47.199999999999996, actual=37.2
# > predicted=40.300000000000004, actual=25.0
# > predicted=26.599999999999998, actual=23.5
# > predicted=29.733333333333334, actual=35.6
# > predicted=45.0, actual=46.1
# > predicted=26.76666666666667, actual=26.2
# > predicted=53.73333333333333, actual=42.7
# > predicted=27.200000000000003, actual=23.9
# > predicted=26.03333333333333, actual=32.1
# > predicted=37.63333333333333, actual=38.3
# > predicted=46.6, actual=40.8
# > predicted=27.7, actual=30.8
# > predicted=32.833333333333336, actual=34.6
# > predicted=31.3, actual=29.3
# > predicted=39.93333333333334, actual=35.5
# > predicted=34.4, actual=34.1
# > predicted=45.06666666666666, actual=54.8
# > predicted=42.79999999999999, actual=42.3
# > predicted=35.4, actual=30.0
# > predicted=25.833333333333332, actual=21.3
# > predicted=40.53333333333333, actual=38.6
# > predicted=25.066666666666666, actual=28.1
# > predicted=43.9, actual=55.0
# > predicted=26.599999999999998, actual=24.4
# > predicted=43.666666666666664, actual=28.5
# > predicted=34.833333333333336, actual=7.6
# > predicted=23.866666666666664, actual=22.3
# > predicted=57.56666666666666, actual=62.1
# > predicted=54.73333333333333, actual=50.0
# > predicted=26.599999999999998, actual=31.3
# > predicted=21.099999999999998, actual=25.7
# > predicted=39.93333333333334, actual=37.5
# > predicted=46.5, actual=39.0
# > predicted=36.0, actual=34.1
# > predicted=37.53333333333333, actual=32.9
# > predicted=40.1, actual=49.3
# > predicted=36.5, actual=57.1
# > predicted=36.6, actual=24.7
# > predicted=48.43333333333334, actual=55.3
# > predicted=47.96666666666667, actual=55.0
# > predicted=43.13333333333333, actual=53.3
# > predicted=22.96666666666667, actual=23.1
# > predicted=27.333333333333332, actual=29.5
# > predicted=35.233333333333334, actual=40.1
# > predicted=21.400000000000002, actual=45.1
# > predicted=68.86666666666666, actual=70.1
# > predicted=49.46666666666667, actual=50.7
# > predicted=40.300000000000004, actual=37.0
# > predicted=54.53333333333333, actual=46.7
# > predicted=18.366666666666664, actual=29.3
# > predicted=56.03333333333333, actual=47.7
# > predicted=14.466666666666667, actual=19.2
# > predicted=25.600000000000005, actual=20.9
# > predicted=25.833333333333332, actual=29.4
# > predicted=43.23333333333333, actual=39.1
# > predicted=40.23333333333334, actual=45.5
# > predicted=29.733333333333334, actual=38.1
# > predicted=32.13333333333333, actual=28.4
# > predicted=45.5, actual=31.5
# > predicted=46.5, actual=36.6
# Root Mean Square Error: 7.8084379464152125%
# ****************************Cosine***************************************
# > predicted=17.066666666666666, actual=45.1
# > predicted=17.066666666666666, actual=42.3
# > predicted=17.066666666666666, actual=52.2
# > predicted=17.066666666666666, actual=37.3
# > predicted=53.73333333333333, actual=22.8
# > predicted=17.066666666666666, actual=36.3
# > predicted=17.066666666666666, actual=53.0
# > predicted=17.066666666666666, actual=51.4
# > predicted=17.066666666666666, actual=16.1
# > predicted=17.066666666666666, actual=59.0
# > predicted=53.73333333333333, actual=30.6
# > predicted=53.73333333333333, actual=30.7
# > predicted=53.73333333333333, actual=35.6
# > predicted=17.066666666666666, actual=13.7
# > predicted=17.066666666666666, actual=62.9
# > predicted=53.73333333333333, actual=30.5
# > predicted=17.066666666666666, actual=41.9
# > predicted=17.066666666666666, actual=54.4
# > predicted=53.73333333333333, actual=29.5
# > predicted=17.066666666666666, actual=43.7
# > predicted=53.73333333333333, actual=12.2
# > predicted=53.73333333333333, actual=22.1
# > predicted=17.066666666666666, actual=49.5
# > predicted=17.066666666666666, actual=47.4
# > predicted=53.73333333333333, actual=18.6
# > predicted=17.066666666666666, actual=28.5
# > predicted=53.73333333333333, actual=14.7
# > predicted=17.066666666666666, actual=45.4
# > predicted=17.066666666666666, actual=41.0
# > predicted=17.066666666666666, actual=35.1
# > predicted=53.73333333333333, actual=22.1
# > predicted=53.73333333333333, actual=28.9
# > predicted=17.066666666666666, actual=30.5
# > predicted=17.066666666666666, actual=26.5
# > predicted=17.066666666666666, actual=49.3
# > predicted=17.066666666666666, actual=37.0
# > predicted=17.066666666666666, actual=56.3
# > predicted=53.73333333333333, actual=15.4
# > predicted=17.066666666666666, actual=48.5
# > predicted=17.066666666666666, actual=63.3
# > predicted=17.066666666666666, actual=50.5
# > predicted=17.066666666666666, actual=42.2
# > predicted=17.066666666666666, actual=37.9
# > predicted=17.066666666666666, actual=37.5
# > predicted=17.066666666666666, actual=40.5
# > predicted=17.066666666666666, actual=57.4
# > predicted=17.066666666666666, actual=26.5
# > predicted=53.73333333333333, actual=21.8
# > predicted=17.066666666666666, actual=49.7
# > predicted=17.066666666666666, actual=47.1
# > predicted=17.066666666666666, actual=49.0
# > predicted=17.066666666666666, actual=60.7
# > predicted=17.066666666666666, actual=33.1
# > predicted=17.066666666666666, actual=41.0
# > predicted=17.066666666666666, actual=36.5
# > predicted=53.73333333333333, actual=20.0
# > predicted=17.066666666666666, actual=34.7
# > predicted=17.066666666666666, actual=30.6
# > predicted=53.73333333333333, actual=25.6
# > predicted=17.066666666666666, actual=46.2
# > predicted=53.73333333333333, actual=27.7
# > predicted=43.199999999999996, actual=27.0
# > predicted=53.73333333333333, actual=15.6
# > predicted=53.73333333333333, actual=15.5
# > predicted=53.73333333333333, actual=11.2
# > predicted=53.73333333333333, actual=23.7
# > predicted=17.066666666666666, actual=24.6
# > predicted=17.066666666666666, actual=42.0
# > predicted=17.066666666666666, actual=29.8
# > predicted=17.066666666666666, actual=28.9
# > predicted=17.066666666666666, actual=48.1
# > predicted=17.066666666666666, actual=36.8
# > predicted=17.066666666666666, actual=53.5
# > predicted=17.066666666666666, actual=51.6
# > predicted=17.066666666666666, actual=38.8
# > predicted=17.066666666666666, actual=37.4
# > predicted=17.066666666666666, actual=40.6
# > predicted=17.066666666666666, actual=37.2
# > predicted=17.066666666666666, actual=25.0
# > predicted=53.73333333333333, actual=23.5
# > predicted=17.066666666666666, actual=35.6
# > predicted=17.066666666666666, actual=46.1
# > predicted=17.066666666666666, actual=26.2
# > predicted=17.066666666666666, actual=42.7
# > predicted=53.73333333333333, actual=23.9
# > predicted=53.73333333333333, actual=32.1
# > predicted=17.066666666666666, actual=38.3
# > predicted=17.066666666666666, actual=40.8
# > predicted=53.73333333333333, actual=30.8
# > predicted=17.066666666666666, actual=34.6
# > predicted=53.73333333333333, actual=29.3
# > predicted=17.066666666666666, actual=35.5
# > predicted=17.066666666666666, actual=34.1
# > predicted=17.066666666666666, actual=54.8
# > predicted=17.066666666666666, actual=42.3
# > predicted=17.066666666666666, actual=30.0
# > predicted=53.73333333333333, actual=21.3
# > predicted=17.066666666666666, actual=38.6
# > predicted=53.73333333333333, actual=28.1
# > predicted=17.066666666666666, actual=55.0
# > predicted=53.73333333333333, actual=24.4
# > predicted=17.066666666666666, actual=28.5
# > predicted=17.066666666666666, actual=7.6
# > predicted=17.066666666666666, actual=22.3
# > predicted=17.066666666666666, actual=62.1
# > predicted=17.066666666666666, actual=50.0
# > predicted=53.73333333333333, actual=31.3
# > predicted=53.73333333333333, actual=25.7
# > predicted=17.066666666666666, actual=37.5
# > predicted=17.066666666666666, actual=39.0
# > predicted=17.066666666666666, actual=34.1
# > predicted=17.066666666666666, actual=32.9
# > predicted=17.066666666666666, actual=49.3
# > predicted=17.066666666666666, actual=57.1
# > predicted=53.73333333333333, actual=24.7
# > predicted=17.066666666666666, actual=55.3
# > predicted=17.066666666666666, actual=55.0
# > predicted=17.066666666666666, actual=53.3
# > predicted=17.066666666666666, actual=23.1
# > predicted=17.066666666666666, actual=29.5
# > predicted=17.066666666666666, actual=40.1
# > predicted=53.73333333333333, actual=45.1
# > predicted=17.066666666666666, actual=70.1
# > predicted=17.066666666666666, actual=50.7
# > predicted=17.066666666666666, actual=37.0
# > predicted=17.066666666666666, actual=46.7
# > predicted=53.73333333333333, actual=29.3
# > predicted=17.066666666666666, actual=47.7
# > predicted=53.73333333333333, actual=19.2
# > predicted=53.73333333333333, actual=20.9
# > predicted=53.73333333333333, actual=29.4
# > predicted=17.066666666666666, actual=39.1
# > predicted=17.066666666666666, actual=45.5
# > predicted=17.066666666666666, actual=38.1
# > predicted=53.73333333333333, actual=28.4
# > predicted=17.066666666666666, actual=31.5
# > predicted=17.066666666666666, actual=36.6
# Root Mean Square Error: 27.611228865237052%
